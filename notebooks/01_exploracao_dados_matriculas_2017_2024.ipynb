# %% [markdown]
#  ### 01 - Exploração e Tratamento dos Dados
# Fonte: Microdados de Matrículas da Plataforma Nilo Peçanha (2017-2024)

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %% [markdown]
# Transformação dos arquivos .csv em Data Frames, selecionando as colunas a serem utilizadas:

# %%
selecao = [
    "Ano", "Carga Horaria", "Carga Horaria Mínima", "Categoria da Situação", 
    "Cor / Raça", "Código da Matricula", "Código do Ciclo Matricula", 
    "Data de Fim Previsto do Ciclo", 
    "Data de Inicio do Ciclo", "Data de Ocorrencia da Matricula", 
    "Eixo Tecnológico", "Faixa Etária", "Fator Esforço Curso", 
    "Idade", "Instituição", "Matrícula Atendida", 
    "Modalidade de Ensino", "Município", "Mês De Ocorrência da Situação", 
    "Nome de Curso", "Renda Familiar", "Sexo", 
    "Situação de Matrícula", "Subeixo Tecnológico", "Tipo de Curso", 
    "Tipo de Oferta", "Total de Inscritos", "Turno", "UF", "Unidade de Ensino"
]


df_2017 = pd.read_csv("../dados_brutos/microdados_matriculas_2017.csv", sep=";", usecols=selecao)
df_2018 = pd.read_csv("../dados_brutos/microdados_matriculas_2018.csv", sep=";", usecols=selecao)
df_2019 = pd.read_csv("../dados_brutos/microdados_matriculas_2019.csv", sep=";", usecols=selecao)
df_2020 = pd.read_csv("../dados_brutos/microdados_matriculas_2020.csv", sep=";", usecols=selecao)
df_2021 = pd.read_csv("../dados_brutos/microdados_matriculas_2021.csv", sep=";", usecols=selecao)
df_2022 = pd.read_csv("../dados_brutos/microdados_matriculas_2022.csv", sep=";", usecols=selecao)
df_2023 = pd.read_csv("../dados_brutos/microdados_matriculas_2023.csv", sep=";", usecols=selecao)
df_2024 = pd.read_csv("../dados_brutos/microdados_matriculas_2024.csv", sep=";", usecols=selecao)


print("Dimensão original 2017:", df_2017.shape)
print("Dimensão original 2018:", df_2018.shape)
print("Dimensão original 2019:", df_2019.shape)
print("Dimensão original 2020:", df_2020.shape)
print("Dimensão original 2021:", df_2021.shape)
print("Dimensão original 2022:", df_2022.shape)
print("Dimensão original 2023:", df_2023.shape)
print("Dimensão original 2024:", df_2024.shape)
# Out:
# Dimensão original 2017: (1031798, 30)
# Dimensão original 2018: (964593, 30)
# Dimensão original 2019: (1023303, 30)
# Dimensão original 2020: (1507476, 30)
# Dimensão original 2021: (1523346, 30)
# Dimensão original 2022: (1513075, 30)
# Dimensão original 2023: (1681363, 30)
# Dimensão original 2024: (1982778, 30)

# %% [markdown]
# Concatenação dos Data Frames gerados e exibição dos primeiros e últimos registros:

# %%
df_2017_2024 = pd.concat([df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023, df_2024])

df_2017_2024.head()
# Out:
#     Ano  Carga Horaria  Carga Horaria Mínima Categoria da Situação Cor / Raça  \
# 0  2017           3140                1200.0              Em curso      Parda
# 1  2017           3140                1200.0              Em curso      Parda
# 2  2017           3140                1200.0              Evadidos      Preta
# 3  2017           3140                1200.0              Em curso      Parda
# 4  2017           3140                1200.0              Em curso      Parda
#
#    Código da Matricula  Código do Ciclo Matricula  \
# 0             72203790                    2152673
# 1             72203780                    2152673
# 2             72203776                    2152673
# 3             72203774                    2152673
# 4             72203772                    2152673
#
#   Data de Fim Previsto do Ciclo Data de Inicio do Ciclo  \
# 0                    31/12/2019              02/03/2017
# 1                    31/12/2019              02/03/2017
# 2                    31/12/2019              02/03/2017
# 3                    31/12/2019              02/03/2017
# 4                    31/12/2019              02/03/2017
#
#   Data de Ocorrencia da Matricula      Eixo Tecnológico  Faixa Etária  \
# 0                      01/03/2017  Produção Alimentícia  15 a 19 anos
# 1                      01/03/2017  Produção Alimentícia  15 a 19 anos
# 2                      01/03/2017  Produção Alimentícia  15 a 19 anos
# 3                      01/03/2017  Produção Alimentícia  15 a 19 anos
# 4                      01/03/2017  Produção Alimentícia  15 a 19 anos
#
#   Fator Esforço Curso  Idade Instituição Matrícula Atendida  \
# 0                1,15   17.0        IFRR                  1
# 1                1,15   17.0        IFRR                  1
# 2                1,15   15.0        IFRR                  1
# 3                1,15   16.0        IFRR                  1
# 4                1,15   15.0        IFRR                  1
#
#   Modalidade de Ensino Município Mês De Ocorrência da Situação  \
# 0  Educação Presencial     Norte                    01/03/2017
# 1  Educação Presencial     Norte                    01/03/2017
# 2  Educação Presencial     Norte                    01/07/2017
# 3  Educação Presencial     Norte                    01/03/2017
# 4  Educação Presencial     Norte                    01/03/2017
#
#               Nome de Curso Renda Familiar Sexo Situação de Matrícula  \
# 0  Técnico em Agroindústria     0,5<RFP<=1    M              Em curso
# 1  Técnico em Agroindústria     1<RFP<=1,5    M              Em curso
# 2  Técnico em Agroindústria     0,5<RFP<=1    M       Transf. externa
# 3  Técnico em Agroindústria        RFP>3,5    F              Em curso
# 4  Técnico em Agroindústria     0,5<RFP<=1    M              Em curso
#
#   Subeixo Tecnológico Tipo de Curso Tipo de Oferta  Total de Inscritos  \
# 0       Agroindustria       Técnico      Integrado                52.0
# 1       Agroindustria       Técnico      Integrado                52.0
# 2       Agroindustria       Técnico      Integrado                52.0
# 3       Agroindustria       Técnico      Integrado                52.0
# 4       Agroindustria       Técnico      Integrado                52.0
#
#       Turno  UF    Unidade de Ensino
# 0  Integral  RR  Campus Novo Paraíso
# 1  Integral  RR  Campus Novo Paraíso
# 2  Integral  RR  Campus Novo Paraíso
# 3  Integral  RR  Campus Novo Paraíso
# 4  Integral  RR  Campus Novo Paraíso

# %%
df_2017_2024.tail()
# Out:
#           Ano  Carga Horaria  Carga Horaria Mínima Categoria da Situação  \
# 1982773  2024           3240                1200.0              Em curso
# 1982774  2024             60                 160.0           Concluintes
# 1982775  2024           3300                 800.0           Concluintes
# 1982776  2024           1050                 800.0           Concluintes
# 1982777  2024           1440                1000.0              Evadidos
#
#         Cor / Raça  Código da Matricula  Código do Ciclo Matricula  \
# 1982773      Parda            109548323                    2965961
# 1982774      Parda            122954788                    3139052
# 1982775      Parda             99499494                    2774414
# 1982776      Parda            106556867                    2906230
# 1982777     Branca            111688442                    2995963
#
#         Data de Fim Previsto do Ciclo Data de Inicio do Ciclo  \
# 1982773                    20/12/2025              27/02/2023
# 1982774                    20/12/2024              01/07/2024
# 1982775                    01/03/2024              03/05/2021
# 1982776                    31/01/2024              09/08/2022
# 1982777                    31/07/2025              20/03/2023
#
#         Data de Ocorrencia da Matricula                  Eixo Tecnológico  \
# 1982773                      01/02/2023  Controle e Processos Industriais
# 1982774                      01/11/2024                 Gestão e Negócios
# 1982775                      01/05/2021                 Gestão e Negócios
# 1982776                      01/08/2022                 Gestão e Negócios
# 1982777                      01/03/2023          Informação e Comunicação
#
#          Faixa Etária Fator Esforço Curso  Idade    Instituição  \
# 1982773  15 a 19 anos                1,12   17.0  IF SUDESTE MG
# 1982774  35 a 39 anos                 1,1   37.0           IFMS
# 1982775  15 a 19 anos               1,008   19.0           IFPI
# 1982776  40 a 44 anos               1,005   42.0           IFPE
# 1982777  20 a 24 anos               1,053   23.0           IFCE
#
#         Matrícula Atendida  Modalidade de Ensino                Município  \
# 1982773                  Y   Educação Presencial                   Muriaé
# 1982774                  Y  Educação a Distância             Campo Grande
# 1982775                  Y   Educação Presencial                   Oeiras
# 1982776                  Y   Educação Presencial  Cabo de Santo Agostinho
# 1982777                  Y   Educação Presencial                  Canindé
#
#         Mês De Ocorrência da Situação  \
# 1982773                    25/02/2023
# 1982774                    25/11/2024
# 1982775                    25/01/2024
# 1982776                    25/02/2024
# 1982777                    25/12/2024
#
#                                          Nome de Curso Renda Familiar Sexo  \
# 1982773                       Técnico em Eletrotécnica     0,5<RFP<=1    F
# 1982774  Qualificação Profissional - Gestão e Negócios     0,5<RFP<=1    M
# 1982775                       Técnico em Administração     0<RFP<=0,5    F
# 1982776                           Técnico em Logística     0,5<RFP<=1    F
# 1982777                         Técnico em Informática  Não declarada    F
#
#         Situação de Matrícula Subeixo Tecnológico  \
# 1982773              Em curso            Elétrica
# 1982774             Concluída   Gestão e Negócios
# 1982775             Concluída   Gestão e Negócios
# 1982776             Concluída   Gestão e Negócios
# 1982777              Abandono         Informática
#
#                            Tipo de Curso Tipo de Oferta  Total de Inscritos  \
# 1982773                          Técnico      Integrado                96.0
# 1982774  Qualificação Profissional (FIC)   Concomitante              1346.0
# 1982775                          Técnico      Integrado               154.0
# 1982776                          Técnico    Subsequente               347.0
# 1982777                          Técnico    Subsequente                35.0
#
#               Turno  UF               Unidade de Ensino
# 1982773    Integral  MG                   Campus Muriaé
# 1982774         NaN  MS             Campus Campo Grande
# 1982775    Matutino  PI                   Campus Oeiras
# 1982776  Vespertino  PE  Campus Cabo de Santo Agostinho
# 1982777     Noturno  CE                  Campus Canindé

# %% [markdown]
# Aplicação de Filtro de Unidade de Ensino = Campus Porto Alegre Restinga:

# %%
df_restinga = df_2017_2024.loc[df_2017_2024["Unidade de Ensino"] == "Campus Porto Alegre Restinga"]
print("Após filtro Campus Restinga:", df_restinga.shape)
# Out:
# Após filtro Campus Restinga: (16850, 30)

# %% [markdown]
# Exclusão de colunas desnecessárias:

# %%
df_restinga = df_restinga.drop(columns=["Instituição", "Município", "UF", "Unidade de Ensino"])
print("Após exclusão de colunas desnecessárias:", df_restinga.shape)
# Out:
# Após exclusão de colunas desnecessárias: (16850, 26)

# %% [markdown]
# Padronização dos nomes dos cursos e limpeza:

# %%
df_restinga.groupby("Nome de Curso").size()
# Out:
# Nome de Curso
# Agente Cultural                                                       36
# Agente de Desenvolvimento Cooperativista                              25
# Análise e Desenvolvimento de Sistemas                               2209
# Confeccionador de Bolsas em Tecido                                    25
# Eletrônica Industrial                                                854
# Gestor de Microempresa                                                29
# Gestão Desportiva e de Lazer                                          84
# Gestão desportiva e de Lazer                                         713
# Letras                                                               177
# Letras - Língua Estrangeira                                          620
# Língua Brasileira de Sinais (Libras) ­ Básico                         25
# Manufatura Avançada (industria 4.0)                                   15
# Monitor de Atividades de Lazer                                        23
# Operador de Computador                                                83
# Processos Gerenciais                                                 764
# Qualificação Profissional - Controle e Processos Industriais          36
# Qualificação Profissional - Desenvolvimento Educacional e Social    5369
# Técnico em Administração                                             168
# Técnico em Agroecologia                                              747
# Técnico em Comércio                                                  754
# Técnico em Eletrônica                                               1076
# Técnico em Guia de Turismo                                           554
# Técnico em Informática                                              1126
# Técnico em Informática Para Internet                                   3
# Técnico em Informática para Internet                                 247
# Técnico em Lazer                                                     769
# Técnico em Recursos Humanos                                          195
# Técnico em Redes de Computadores                                     124
# dtype: int64

# %% [markdown]
# Seleção dos cursos Técnicos e Superiores do Campus Restinga:

# %%
df_restinga["Tipo de Curso"].unique()
# Out:
# array(['Tecnologia', 'Técnico', 'Licenciatura',
#        'Qualificação Profissional (FIC)', 'Especialização (Lato Sensu)'],
#       dtype=object)

# %%
df_restinga = df_restinga[
    df_restinga["Tipo de Curso"].isin(["Licenciatura", "Técnico", "Tecnologia"])
]

# %%
df_contagem = df_restinga.groupby("Nome de Curso").size()
df_contagem
# Out:
# Nome de Curso
# Análise e Desenvolvimento de Sistemas    2209
# Eletrônica Industrial                     854
# Gestão Desportiva e de Lazer               84
# Gestão desportiva e de Lazer              713
# Letras                                    177
# Letras - Língua Estrangeira               620
# Processos Gerenciais                      764
# Técnico em Administração                  168
# Técnico em Agroecologia                   747
# Técnico em Comércio                       754
# Técnico em Eletrônica                    1076
# Técnico em Guia de Turismo                554
# Técnico em Informática                   1126
# Técnico em Informática Para Internet        3
# Técnico em Informática para Internet      247
# Técnico em Lazer                          769
# Técnico em Recursos Humanos               195
# Técnico em Redes de Computadores          124
# dtype: int64

# %%
df_restinga["Código da Matricula"].count()
# Out:
# np.int64(11184)

# %% [markdown]
# Limpeza de cursos extintos e padronização dos nomes dos cursos:

# %%
cursos_excluir = [
    "Técnico em Administração",
    "Técnico em Informática Para Internet",
    "Técnico em Informática para Internet",
    "Técnico em Recursos Humanos",
    "Técnico em Redes de Computadores"
]

df_restinga = df_restinga[
    ~df_restinga["Nome de Curso"].isin(cursos_excluir)
]

df_restinga.loc[:, "Nome de Curso"] = df_restinga["Nome de Curso"].replace({
    "Gestão desportiva e de Lazer": "Gestão Desportiva e de Lazer",
    "Letras": "Letras - Português e Espanhol",
    "Letras - Língua Estrangeira": "Letras - Português e Espanhol"
})

df_restinga["Nome de Curso"].unique()
# Out:
# array(['Análise e Desenvolvimento de Sistemas', 'Técnico em Eletrônica',
#        'Gestão Desportiva e de Lazer', 'Eletrônica Industrial',
#        'Técnico em Informática', 'Técnico em Guia de Turismo',
#        'Técnico em Comércio', 'Técnico em Lazer',
#        'Letras - Português e Espanhol', 'Processos Gerenciais',
#        'Técnico em Agroecologia'], dtype=object)

# %% [markdown]
# Lidando com os valores nulos:

# %%
df_restinga.isnull().sum()   # df_restinga.isna().sum()  #esse comando é equivalente
# Out:
# Ano                                   0
# Carga Horaria                         0
# Carga Horaria Mínima                  0
# Categoria da Situação                 0
# Cor / Raça                            0
# Código da Matricula                   0
# Código do Ciclo Matricula             0
# Data de Fim Previsto do Ciclo         0
# Data de Inicio do Ciclo               0
# Data de Ocorrencia da Matricula       0
# Eixo Tecnológico                      0
# Faixa Etária                          0
# Fator Esforço Curso                   0
# Idade                                 0
# Matrícula Atendida                    0
# Modalidade de Ensino                  0
# Mês De Ocorrência da Situação         2
# Nome de Curso                         0
# Renda Familiar                        0
# Sexo                                  0
# Situação de Matrícula                 0
# Subeixo Tecnológico                   0
# Tipo de Curso                         0
# Tipo de Oferta                        0
# Total de Inscritos                 1978
# Turno                                 0
# dtype: int64

# %%
#retirar coluna total inscritos = não tem nos anos 2020-2021
df_restinga = df_restinga.drop(columns=["Total de Inscritos"])
print("Após exclusão de colunas desnecessárias:", df_restinga.shape)
# Out:
# Após exclusão de colunas desnecessárias: (10447, 25)

# %%
#retirar as 2 linhas com valores nulos do mês de ocorrência

df_restinga.dropna(subset=["Mês De Ocorrência da Situação"], inplace=True) #inplace=True para salvar a retirada dos nulos --- verificar se faremos assim

print("Após exclusão de linhas desnecessárias:", df_restinga.shape)
# Out:
# Após exclusão de linhas desnecessárias: (10445, 25)

# %%
df_restinga.isnull().sum()
# Out:
# Ano                                0
# Carga Horaria                      0
# Carga Horaria Mínima               0
# Categoria da Situação              0
# Cor / Raça                         0
# Código da Matricula                0
# Código do Ciclo Matricula          0
# Data de Fim Previsto do Ciclo      0
# Data de Inicio do Ciclo            0
# Data de Ocorrencia da Matricula    0
# Eixo Tecnológico                   0
# Faixa Etária                       0
# Fator Esforço Curso                0
# Idade                              0
# Matrícula Atendida                 0
# Modalidade de Ensino               0
# Mês De Ocorrência da Situação      0
# Nome de Curso                      0
# Renda Familiar                     0
# Sexo                               0
# Situação de Matrícula              0
# Subeixo Tecnológico                0
# Tipo de Curso                      0
# Tipo de Oferta                     0
# Turno                              0
# dtype: int64

# %% [markdown]
# Verificar os tipos de dados:

# %%
df_restinga.dtypes
# Out:
# Ano                                  int64
# Carga Horaria                        int64
# Carga Horaria Mínima               float64
# Categoria da Situação               object
# Cor / Raça                          object
# Código da Matricula                  int64
# Código do Ciclo Matricula            int64
# Data de Fim Previsto do Ciclo       object
# Data de Inicio do Ciclo             object
# Data de Ocorrencia da Matricula     object
# Eixo Tecnológico                    object
# Faixa Etária                        object
# Fator Esforço Curso                 object
# Idade                              float64
# Matrícula Atendida                  object
# Modalidade de Ensino                object
# Mês De Ocorrência da Situação       object
# Nome de Curso                       object
# Renda Familiar                      object
# Sexo                                object
# Situação de Matrícula               object
# Subeixo Tecnológico                 object
# Tipo de Curso                       object
# Tipo de Oferta                      object
# Turno                               object
# dtype: object

# %% [markdown]
# Lidando com as datas:

# %%
df_restinga.loc[:, "Data de Fim Previso do Ciclo"] = pd.to_datetime(
    df_restinga["Data de Fim Previsto do Ciclo"],
    dayfirst=True,
)

df_restinga.dtypes
# Out:
# Ano                                         int64
# Carga Horaria                               int64
# Carga Horaria Mínima                      float64
# Categoria da Situação                      object
# Cor / Raça                                 object
# Código da Matricula                         int64
# Código do Ciclo Matricula                   int64
# Data de Fim Previsto do Ciclo              object
# Data de Inicio do Ciclo                    object
# Data de Ocorrencia da Matricula            object
# Eixo Tecnológico                           object
# Faixa Etária                               object
# Fator Esforço Curso                        object
# Idade                                     float64
# Matrícula Atendida                         object
# Modalidade de Ensino                       object
# Mês De Ocorrência da Situação              object
# Nome de Curso                              object
# Renda Familiar                             object
# Sexo                                       object
# Situação de Matrícula                      object
# Subeixo Tecnológico                        object
# Tipo de Curso                              object
# Tipo de Oferta                             object
# Turno                                      object
# Data de Fim Previso do Ciclo       datetime64[ns]
# dtype: object

# %%
df_restinga["Data de Ocorrencia da Matricula"] = pd.to_datetime(
    df_restinga["Data de Ocorrencia da Matricula"],
    dayfirst=True,
    errors='coerce'
)

df_restinga.dtypes
# Out:
# Ano                                         int64
# Carga Horaria                               int64
# Carga Horaria Mínima                      float64
# Categoria da Situação                      object
# Cor / Raça                                 object
# Código da Matricula                         int64
# Código do Ciclo Matricula                   int64
# Data de Fim Previsto do Ciclo              object
# Data de Inicio do Ciclo                    object
# Data de Ocorrencia da Matricula    datetime64[ns]
# Eixo Tecnológico                           object
# Faixa Etária                               object
# Fator Esforço Curso                        object
# Idade                                     float64
# Matrícula Atendida                         object
# Modalidade de Ensino                       object
# Mês De Ocorrência da Situação              object
# Nome de Curso                              object
# Renda Familiar                             object
# Sexo                                       object
# Situação de Matrícula                      object
# Subeixo Tecnológico                        object
# Tipo de Curso                              object
# Tipo de Oferta                             object
# Turno                                      object
# Data de Fim Previso do Ciclo       datetime64[ns]
# dtype: object

# %%
df_restinga["Mês De Ocorrência da Situação"] = pd.to_datetime(
    df_restinga["Mês De Ocorrência da Situação"],
    dayfirst=True,
    errors='coerce'
)

df_restinga.dtypes
# Out:
# Ano                                         int64
# Carga Horaria                               int64
# Carga Horaria Mínima                      float64
# Categoria da Situação                      object
# Cor / Raça                                 object
# Código da Matricula                         int64
# Código do Ciclo Matricula                   int64
# Data de Fim Previsto do Ciclo              object
# Data de Inicio do Ciclo                    object
# Data de Ocorrencia da Matricula    datetime64[ns]
# Eixo Tecnológico                           object
# Faixa Etária                               object
# Fator Esforço Curso                        object
# Idade                                     float64
# Matrícula Atendida                         object
# Modalidade de Ensino                       object
# Mês De Ocorrência da Situação      datetime64[ns]
# Nome de Curso                              object
# Renda Familiar                             object
# Sexo                                       object
# Situação de Matrícula                      object
# Subeixo Tecnológico                        object
# Tipo de Curso                              object
# Tipo de Oferta                             object
# Turno                                      object
# Data de Fim Previso do Ciclo       datetime64[ns]
# dtype: object

# %%
df_restinga.info(memory_usage='deep') #para verificar a utilização de memória real
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10445 entries, 20729 to 1981342
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano                              10445 non-null  int64
#  1   Carga Horaria                    10445 non-null  int64
#  2   Carga Horaria Mínima             10445 non-null  float64
#  3   Categoria da Situação            10445 non-null  object
#  4   Cor / Raça                       10445 non-null  object
#  5   Código da Matricula              10445 non-null  int64
#  6   Código do Ciclo Matricula        10445 non-null  int64
#  7   Data de Fim Previsto do Ciclo    10445 non-null  object
#  8   Data de Inicio do Ciclo          10445 non-null  object
#  9   Data de Ocorrencia da Matricula  10445 non-null  datetime64[ns]
#  10  Eixo Tecnológico                 10445 non-null  object
#  11  Faixa Etária                     10445 non-null  object
#  12  Fator Esforço Curso              10445 non-null  object
#  13  Idade                            10445 non-null  float64
#  14  Matrícula Atendida               10445 non-null  object
#  15  Modalidade de Ensino             10445 non-null  object
#  16  Mês De Ocorrência da Situação    10445 non-null  datetime64[ns]
#  17  Nome de Curso                    10445 non-null  object
#  18  Renda Familiar                   10445 non-null  object
#  19  Sexo                             10445 non-null  object
#  20  Situação de Matrícula            10445 non-null  object
#  21  Subeixo Tecnológico              10445 non-null  object
#  22  Tipo de Curso                    10445 non-null  object
#  23  Tipo de Oferta                   10445 non-null  object
#  24  Turno                            10445 non-null  object
#  25  Data de Fim Previso do Ciclo     10445 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), int64(4), object(17)
# memory usage: 12.0 MB

# %%
df_restinga.describe()
# Out:
#                 Ano  Carga Horaria  Carga Horaria Mínima  Código da Matricula  \
# count  10445.000000   10445.000000          10445.000000         1.044500e+04
# mean    2021.014935    2574.517855           1517.568214         8.920631e+07
# min     2017.000000     965.000000            800.000000         3.480875e+07
# 25%     2019.000000    2082.000000           1000.000000         8.534632e+07
# 50%     2021.000000    2405.000000           1600.000000         8.958825e+07
# 75%     2023.000000    3490.000000           2000.000000         1.001396e+08
# max     2024.000000    3893.000000           2400.000000         1.229860e+08
# std        2.253804     772.177465            567.613939         1.499799e+07
#
#        Código do Ciclo Matricula Data de Ocorrencia da Matricula  \
# count               1.044500e+04                           10445
# mean                2.538103e+06   2019-05-17 17:27:29.899473408
# min                 7.923820e+05             2011-02-01 00:00:00
# 25%                 2.191306e+06             2017-08-01 00:00:00
# 50%                 2.571566e+06             2019-02-01 00:00:00
# 75%                 2.784564e+06             2021-10-01 00:00:00
# max                 3.154254e+06             2024-09-01 00:00:00
# std                 3.282016e+05                             NaN
#
#               Idade  Mês De Ocorrência da Situação  \
# count  10445.000000                          10445
# mean      29.059742  2019-12-02 09:48:49.286740224
# min       14.000000            2013-03-25 00:00:00
# 25%       20.000000            2018-03-01 00:00:00
# 50%       25.000000            2019-07-01 00:00:00
# 75%       36.000000            2022-04-01 00:00:00
# max       79.000000            2025-01-25 00:00:00
# std       11.586670                            NaN
#
#         Data de Fim Previso do Ciclo
# count                          10445
# mean   2022-06-23 07:15:22.661560576
# min              2014-12-22 00:00:00
# 25%              2020-12-15 00:00:00
# 50%              2021-12-18 00:00:00
# 75%              2023-12-31 00:00:00
# max              2027-12-30 00:00:00
# std                              NaN

# %% [markdown]
# Testando alguns agrupamentos:

# %%
contagem_matriculas_ano_curso = df_restinga.groupby(["Ano", "Nome de Curso"])["Código da Matricula"].count().reset_index() #resetamos o index para permitir agrupar/salvar em excel/csv
print(contagem_matriculas_ano_curso)
# Out:
#      Ano                          Nome de Curso  Código da Matricula
# 0   2017  Análise e Desenvolvimento de Sistemas                  247
# 1   2017                  Eletrônica Industrial                   84
# 2   2017           Gestão Desportiva e de Lazer                  112
# 3   2017          Letras - Português e Espanhol                   30
# 4   2017                    Técnico em Comércio                   33
# ..   ...                                    ...                  ...
# 81  2024                    Técnico em Comércio                  127
# 82  2024                  Técnico em Eletrônica                  164
# 83  2024             Técnico em Guia de Turismo                   77
# 84  2024                 Técnico em Informática                  217
# 85  2024                       Técnico em Lazer                  117
#
# [86 rows x 3 columns]

# %%
df_restinga.to_csv("teste_restinga_dados_preparados.csv", index=False)
