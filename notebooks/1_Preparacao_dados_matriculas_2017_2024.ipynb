# %% [markdown]
#  ## 1 - Preparação dos Dados
# Fonte: Microdados de Matrículas da Plataforma Nilo Peçanha (2017-2024)

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %% [markdown]
# #### 1.1 Transformação dos arquivos .csv em Data Frames, selecionando as colunas a serem utilizadas:

# %%
selecao = [
    "Ano", "Categoria da Situação", "Cor / Raça", "Código da Matricula", "Código do Ciclo Matricula", 
    "Data de Fim Previsto do Ciclo", "Data de Inicio do Ciclo", "Data de Ocorrencia da Matricula", 
    "Eixo Tecnológico", "Faixa Etária", "Instituição", "Município", "Mês De Ocorrência da Situação", 
    "Nome de Curso", "Renda Familiar", "Sexo", "Situação de Matrícula", "Subeixo Tecnológico", 
    "Tipo de Curso", "Tipo de Oferta", "Total de Inscritos", "Turno", "UF", "Unidade de Ensino"
]


df_2017 = pd.read_csv("../dados_brutos/microdados_matriculas_2017.csv", sep=";", usecols=selecao)
df_2018 = pd.read_csv("../dados_brutos/microdados_matriculas_2018.csv", sep=";", usecols=selecao)
df_2019 = pd.read_csv("../dados_brutos/microdados_matriculas_2019.csv", sep=";", usecols=selecao)
df_2020 = pd.read_csv("../dados_brutos/microdados_matriculas_2020.csv", sep=";", usecols=selecao)
df_2021 = pd.read_csv("../dados_brutos/microdados_matriculas_2021.csv", sep=";", usecols=selecao)
df_2022 = pd.read_csv("../dados_brutos/microdados_matriculas_2022.csv", sep=";", usecols=selecao)
df_2023 = pd.read_csv("../dados_brutos/microdados_matriculas_2023.csv", sep=";", usecols=selecao)
df_2024 = pd.read_csv("../dados_brutos/microdados_matriculas_2024.csv", sep=";", usecols=selecao)


print("Dimensão original 2017:", df_2017.shape)
print("Dimensão original 2018:", df_2018.shape)
print("Dimensão original 2019:", df_2019.shape)
print("Dimensão original 2020:", df_2020.shape)
print("Dimensão original 2021:", df_2021.shape)
print("Dimensão original 2022:", df_2022.shape)
print("Dimensão original 2023:", df_2023.shape)
print("Dimensão original 2024:", df_2024.shape)
# Out:
# Dimensão original 2017: (1031798, 24)
# Dimensão original 2018: (964593, 24)
# Dimensão original 2019: (1023303, 24)
# Dimensão original 2020: (1507476, 24)
# Dimensão original 2021: (1523346, 24)
# Dimensão original 2022: (1513075, 24)
# Dimensão original 2023: (1681363, 24)
# Dimensão original 2024: (1982778, 24)

# %% [markdown]
# #### 1.2 Concatenação dos Data Frames gerados e exibição dos primeiros e últimos registros:

# %%
df_2017_2024 = pd.concat([df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023, df_2024])

df_2017_2024.head()
# Out:
#     Ano Categoria da Situação Cor / Raça  Código da Matricula  \
# 0  2017              Em curso      Parda             72203790
# 1  2017              Em curso      Parda             72203780
# 2  2017              Evadidos      Preta             72203776
# 3  2017              Em curso      Parda             72203774
# 4  2017              Em curso      Parda             72203772
#
#    Código do Ciclo Matricula Data de Fim Previsto do Ciclo  \
# 0                    2152673                    31/12/2019
# 1                    2152673                    31/12/2019
# 2                    2152673                    31/12/2019
# 3                    2152673                    31/12/2019
# 4                    2152673                    31/12/2019
#
#   Data de Inicio do Ciclo Data de Ocorrencia da Matricula  \
# 0              02/03/2017                      01/03/2017
# 1              02/03/2017                      01/03/2017
# 2              02/03/2017                      01/03/2017
# 3              02/03/2017                      01/03/2017
# 4              02/03/2017                      01/03/2017
#
#        Eixo Tecnológico  Faixa Etária Instituição Município  \
# 0  Produção Alimentícia  15 a 19 anos        IFRR     Norte
# 1  Produção Alimentícia  15 a 19 anos        IFRR     Norte
# 2  Produção Alimentícia  15 a 19 anos        IFRR     Norte
# 3  Produção Alimentícia  15 a 19 anos        IFRR     Norte
# 4  Produção Alimentícia  15 a 19 anos        IFRR     Norte
#
#   Mês De Ocorrência da Situação             Nome de Curso Renda Familiar Sexo  \
# 0                    01/03/2017  Técnico em Agroindústria     0,5<RFP<=1    M
# 1                    01/03/2017  Técnico em Agroindústria     1<RFP<=1,5    M
# 2                    01/07/2017  Técnico em Agroindústria     0,5<RFP<=1    M
# 3                    01/03/2017  Técnico em Agroindústria        RFP>3,5    F
# 4                    01/03/2017  Técnico em Agroindústria     0,5<RFP<=1    M
#
#   Situação de Matrícula Subeixo Tecnológico Tipo de Curso Tipo de Oferta  \
# 0              Em curso       Agroindustria       Técnico      Integrado
# 1              Em curso       Agroindustria       Técnico      Integrado
# 2       Transf. externa       Agroindustria       Técnico      Integrado
# 3              Em curso       Agroindustria       Técnico      Integrado
# 4              Em curso       Agroindustria       Técnico      Integrado
#
#    Total de Inscritos     Turno  UF    Unidade de Ensino
# 0                52.0  Integral  RR  Campus Novo Paraíso
# 1                52.0  Integral  RR  Campus Novo Paraíso
# 2                52.0  Integral  RR  Campus Novo Paraíso
# 3                52.0  Integral  RR  Campus Novo Paraíso
# 4                52.0  Integral  RR  Campus Novo Paraíso

# %%
df_2017_2024.tail()
# Out:
#           Ano Categoria da Situação Cor / Raça  Código da Matricula  \
# 1982773  2024              Em curso      Parda            109548323
# 1982774  2024           Concluintes      Parda            122954788
# 1982775  2024           Concluintes      Parda             99499494
# 1982776  2024           Concluintes      Parda            106556867
# 1982777  2024              Evadidos     Branca            111688442
#
#          Código do Ciclo Matricula Data de Fim Previsto do Ciclo  \
# 1982773                    2965961                    20/12/2025
# 1982774                    3139052                    20/12/2024
# 1982775                    2774414                    01/03/2024
# 1982776                    2906230                    31/01/2024
# 1982777                    2995963                    31/07/2025
#
#         Data de Inicio do Ciclo Data de Ocorrencia da Matricula  \
# 1982773              27/02/2023                      01/02/2023
# 1982774              01/07/2024                      01/11/2024
# 1982775              03/05/2021                      01/05/2021
# 1982776              09/08/2022                      01/08/2022
# 1982777              20/03/2023                      01/03/2023
#
#                          Eixo Tecnológico  Faixa Etária    Instituição  \
# 1982773  Controle e Processos Industriais  15 a 19 anos  IF SUDESTE MG
# 1982774                 Gestão e Negócios  35 a 39 anos           IFMS
# 1982775                 Gestão e Negócios  15 a 19 anos           IFPI
# 1982776                 Gestão e Negócios  40 a 44 anos           IFPE
# 1982777          Informação e Comunicação  20 a 24 anos           IFCE
#
#                        Município Mês De Ocorrência da Situação  \
# 1982773                   Muriaé                    25/02/2023
# 1982774             Campo Grande                    25/11/2024
# 1982775                   Oeiras                    25/01/2024
# 1982776  Cabo de Santo Agostinho                    25/02/2024
# 1982777                  Canindé                    25/12/2024
#
#                                          Nome de Curso Renda Familiar Sexo  \
# 1982773                       Técnico em Eletrotécnica     0,5<RFP<=1    F
# 1982774  Qualificação Profissional - Gestão e Negócios     0,5<RFP<=1    M
# 1982775                       Técnico em Administração     0<RFP<=0,5    F
# 1982776                           Técnico em Logística     0,5<RFP<=1    F
# 1982777                         Técnico em Informática  Não declarada    F
#
#         Situação de Matrícula Subeixo Tecnológico  \
# 1982773              Em curso            Elétrica
# 1982774             Concluída   Gestão e Negócios
# 1982775             Concluída   Gestão e Negócios
# 1982776             Concluída   Gestão e Negócios
# 1982777              Abandono         Informática
#
#                            Tipo de Curso Tipo de Oferta  Total de Inscritos  \
# 1982773                          Técnico      Integrado                96.0
# 1982774  Qualificação Profissional (FIC)   Concomitante              1346.0
# 1982775                          Técnico      Integrado               154.0
# 1982776                          Técnico    Subsequente               347.0
# 1982777                          Técnico    Subsequente                35.0
#
#               Turno  UF               Unidade de Ensino
# 1982773    Integral  MG                   Campus Muriaé
# 1982774         NaN  MS             Campus Campo Grande
# 1982775    Matutino  PI                   Campus Oeiras
# 1982776  Vespertino  PE  Campus Cabo de Santo Agostinho
# 1982777     Noturno  CE                  Campus Canindé

# %% [markdown]
# #### 1.3 Aplicação de Filtro de Unidade de Ensino = Campus Porto Alegre Restinga:

# %%
df_restinga = df_2017_2024.loc[df_2017_2024["Unidade de Ensino"] == "Campus Porto Alegre Restinga"]
print("Após filtro Campus Restinga:", df_restinga.shape)
# Out:
# Após filtro Campus Restinga: (16850, 24)

# %% [markdown]
# #### 1.4 Exclusão de colunas desnecessárias ("Instituição", "Município", "UF", "Unidade de Ensino"):

# %%
df_restinga = df_restinga.drop(columns=["Instituição", "Município", "UF", "Unidade de Ensino"])
print("Após exclusão de colunas desnecessárias:", df_restinga.shape)
# Out:
# Após exclusão de colunas desnecessárias: (16850, 20)

# %% [markdown]
# #### 1.5 Verificação dos nomes dos cursos do Campus Restinga:

# %%
df_restinga.groupby("Nome de Curso").size()
# Out:
# Nome de Curso
# Agente Cultural                                                       36
# Agente de Desenvolvimento Cooperativista                              25
# Análise e Desenvolvimento de Sistemas                               2209
# Confeccionador de Bolsas em Tecido                                    25
# Eletrônica Industrial                                                854
# Gestor de Microempresa                                                29
# Gestão Desportiva e de Lazer                                          84
# Gestão desportiva e de Lazer                                         713
# Letras                                                               177
# Letras - Língua Estrangeira                                          620
# Língua Brasileira de Sinais (Libras) ­ Básico                         25
# Manufatura Avançada (industria 4.0)                                   15
# Monitor de Atividades de Lazer                                        23
# Operador de Computador                                                83
# Processos Gerenciais                                                 764
# Qualificação Profissional - Controle e Processos Industriais          36
# Qualificação Profissional - Desenvolvimento Educacional e Social    5369
# Técnico em Administração                                             168
# Técnico em Agroecologia                                              747
# Técnico em Comércio                                                  754
# Técnico em Eletrônica                                               1076
# Técnico em Guia de Turismo                                           554
# Técnico em Informática                                              1126
# Técnico em Informática Para Internet                                   3
# Técnico em Informática para Internet                                 247
# Técnico em Lazer                                                     769
# Técnico em Recursos Humanos                                          195
# Técnico em Redes de Computadores                                     124
# dtype: int64

# %% [markdown]
# #### 1.6 Seleção dos cursos Técnicos e Superiores do Campus Restinga:

# %%
df_restinga["Tipo de Curso"].unique()
# Out:
# array(['Tecnologia', 'Técnico', 'Licenciatura',
#        'Qualificação Profissional (FIC)', 'Especialização (Lato Sensu)'],
#       dtype=object)

# %%
df_restinga = df_restinga[
    df_restinga["Tipo de Curso"].isin(["Licenciatura", "Técnico", "Tecnologia"])
]

# %%
# verificação dos nomes após seleção dos cursos técnicos e superiores:
df_contagem = df_restinga.groupby("Nome de Curso").size()
print(df_contagem)
# Out:
# Nome de Curso
# Análise e Desenvolvimento de Sistemas    2209
# Eletrônica Industrial                     854
# Gestão Desportiva e de Lazer               84
# Gestão desportiva e de Lazer              713
# Letras                                    177
# Letras - Língua Estrangeira               620
# Processos Gerenciais                      764
# Técnico em Administração                  168
# Técnico em Agroecologia                   747
# Técnico em Comércio                       754
# Técnico em Eletrônica                    1076
# Técnico em Guia de Turismo                554
# Técnico em Informática                   1126
# Técnico em Informática Para Internet        3
# Técnico em Informática para Internet      247
# Técnico em Lazer                          769
# Técnico em Recursos Humanos               195
# Técnico em Redes de Computadores          124
# dtype: int64

# %% [markdown]
# #### 1.7 Limpeza dos cursos extintos e padronização dos nomes:

# %%
cursos_excluir = [
    "Técnico em Administração",
    "Técnico em Informática Para Internet",
    "Técnico em Informática para Internet",
    "Técnico em Recursos Humanos",
    "Técnico em Redes de Computadores"
]

df_restinga = df_restinga[
    ~df_restinga["Nome de Curso"].isin(cursos_excluir)
]

df_restinga.loc[:, "Nome de Curso"] = df_restinga["Nome de Curso"].replace({
    "Gestão desportiva e de Lazer": "Gestão Desportiva e de Lazer",
    "Letras": "Letras - Português e Espanhol",
    "Letras - Língua Estrangeira": "Letras - Português e Espanhol"
})

df_restinga["Nome de Curso"].unique()
# Out:
# array(['Análise e Desenvolvimento de Sistemas', 'Técnico em Eletrônica',
#        'Gestão Desportiva e de Lazer', 'Eletrônica Industrial',
#        'Técnico em Informática', 'Técnico em Guia de Turismo',
#        'Técnico em Comércio', 'Técnico em Lazer',
#        'Letras - Português e Espanhol', 'Processos Gerenciais',
#        'Técnico em Agroecologia'], dtype=object)

# %% [markdown]
# #### 1.8 Verificando os valores ausentes:

# %%
df_restinga.isnull().sum()
# Out:
# Ano                                   0
# Categoria da Situação                 0
# Cor / Raça                            0
# Código da Matricula                   0
# Código do Ciclo Matricula             0
# Data de Fim Previsto do Ciclo         0
# Data de Inicio do Ciclo               0
# Data de Ocorrencia da Matricula       0
# Eixo Tecnológico                      0
# Faixa Etária                          0
# Mês De Ocorrência da Situação         2
# Nome de Curso                         0
# Renda Familiar                        0
# Sexo                                  0
# Situação de Matrícula                 0
# Subeixo Tecnológico                   0
# Tipo de Curso                         0
# Tipo de Oferta                        0
# Total de Inscritos                 1978
# Turno                                 0
# dtype: int64

# %% [markdown]
# #### 1.9 Tratamento dos valores ausentes:

# %%
#retirar coluna total inscritos, porque não será necessária ao cálculo dos indicadores
df_restinga = df_restinga.drop(columns=["Total de Inscritos"])
print("Após exclusão de total de inscritos:", df_restinga.shape)
# Out:
# Após exclusão de total de inscritos: (10447, 19)

# %%
#retirar as 2 linhas com valores nulos do mês de ocorrência

df_restinga.dropna(subset=["Mês De Ocorrência da Situação"], inplace=True) 

print("Após exclusão de linhas desnecessárias:", df_restinga.shape)
# Out:
# Após exclusão de linhas desnecessárias: (10445, 19)

# %%
df_restinga.isnull().sum()
# Out:
# Ano                                0
# Categoria da Situação              0
# Cor / Raça                         0
# Código da Matricula                0
# Código do Ciclo Matricula          0
# Data de Fim Previsto do Ciclo      0
# Data de Inicio do Ciclo            0
# Data de Ocorrencia da Matricula    0
# Eixo Tecnológico                   0
# Faixa Etária                       0
# Mês De Ocorrência da Situação      0
# Nome de Curso                      0
# Renda Familiar                     0
# Sexo                               0
# Situação de Matrícula              0
# Subeixo Tecnológico                0
# Tipo de Curso                      0
# Tipo de Oferta                     0
# Turno                              0
# dtype: int64

# %% [markdown]
# #### 1.10 Verificando os tipos de dados:

# %%
df_restinga.dtypes
# Out:
# Ano                                 int64
# Categoria da Situação              object
# Cor / Raça                         object
# Código da Matricula                 int64
# Código do Ciclo Matricula           int64
# Data de Fim Previsto do Ciclo      object
# Data de Inicio do Ciclo            object
# Data de Ocorrencia da Matricula    object
# Eixo Tecnológico                   object
# Faixa Etária                       object
# Mês De Ocorrência da Situação      object
# Nome de Curso                      object
# Renda Familiar                     object
# Sexo                               object
# Situação de Matrícula              object
# Subeixo Tecnológico                object
# Tipo de Curso                      object
# Tipo de Oferta                     object
# Turno                              object
# dtype: object

# %% [markdown]
# #### 1.11 Convertendo os tipos de dados:

# %%
df_restinga["Data de Fim Previsto do Ciclo"] = pd.to_datetime(
    df_restinga["Data de Fim Previsto do Ciclo"],
    dayfirst=True,
    errors='coerce'
)

df_restinga["Data de Inicio do Ciclo"] = pd.to_datetime(
    df_restinga["Data de Inicio do Ciclo"],
    dayfirst=True,
    errors='coerce'
)
df_restinga["Data de Ocorrencia da Matricula"] = pd.to_datetime(
    df_restinga["Data de Ocorrencia da Matricula"],
    dayfirst=True,
    errors='coerce'
)

df_restinga["Mês De Ocorrência da Situação"] = pd.to_datetime(
    df_restinga["Mês De Ocorrência da Situação"],
    dayfirst=True,
    errors='coerce'
)

df_restinga.dtypes
# Out:
# Ano                                         int64
# Categoria da Situação                      object
# Cor / Raça                                 object
# Código da Matricula                         int64
# Código do Ciclo Matricula                   int64
# Data de Fim Previsto do Ciclo      datetime64[ns]
# Data de Inicio do Ciclo            datetime64[ns]
# Data de Ocorrencia da Matricula    datetime64[ns]
# Eixo Tecnológico                           object
# Faixa Etária                               object
# Mês De Ocorrência da Situação      datetime64[ns]
# Nome de Curso                              object
# Renda Familiar                             object
# Sexo                                       object
# Situação de Matrícula                      object
# Subeixo Tecnológico                        object
# Tipo de Curso                              object
# Tipo de Oferta                             object
# Turno                                      object
# dtype: object

# %% [markdown]
# #### 1.12 Ajustes das situações de matrícula:

# %%
df_restinga["Situação de Matrícula"].unique() # não há matrículas na situação Cancelada ou Reprovada (conforme PEPE)
# Out:
# array(['Em curso', 'Transf. externa', 'Desligada', 'Abandono',
#        'Concluída', 'Integralizada', 'Transf. interna'], dtype=object)

# %%
# Ajuste das matrículas Em curso para Retido ou Em fluxo:
periodo_fim_previsto = df_restinga["Data de Fim Previsto do Ciclo"].dt.to_period("M")
periodo_referencia = pd.PeriodIndex.from_fields(
    year=df_restinga["Ano"], month=12, freq="M"
)

df_restinga.loc[df_restinga["Situação de Matrícula"] == "Em curso", "Situação de Matrícula"] = np.where(
    periodo_fim_previsto[df_restinga["Situação de Matrícula"] == "Em curso"] < periodo_referencia[df_restinga["Situação de Matrícula"] == "Em curso"],
    "Retido",
    "Em fluxo"
)

# Ajuste das matrículas Em fluxo para identificar os Ingressantes:
df_restinga.loc[(df_restinga["Situação de Matrícula"] == "Em fluxo") & (df_restinga["Data de Inicio do Ciclo"].dt.year == df_restinga["Ano"]), "Situação de Matrícula"] = "Ingressante"


# Ajuste das matrículas Concluída para Concluída no prazo ou Concluída com atraso:
periodo_conclusao = df_restinga["Mês De Ocorrência da Situação"].dt.to_period("M")

diferenca_meses = (df_restinga["Mês De Ocorrência da Situação"].dt.year - df_restinga["Data de Fim Previsto do Ciclo"].dt.year) * 12 + (df_restinga["Mês De Ocorrência da Situação"].dt.month - df_restinga["Data de Fim Previsto do Ciclo"].dt.month)

# Classificação: se o período de fim previsto é menor ou igual a 5 meses do mês de conclusão, considerei concluída no prazo
df_restinga.loc[df_restinga["Situação de Matrícula"] == "Concluída", "Situação de Matrícula"] = np.where(
    diferenca_meses[df_restinga["Situação de Matrícula"] == "Concluída"] <= 5,
    "Concluída no prazo",
    "Concluída com atraso"
)


df_restinga["Situação de Matrícula"].value_counts()
# Out:
# Situação de Matrícula
# Em fluxo                4204
# Ingressante             2480
# Retido                  2316
# Abandono                 449
# Concluída no prazo       379
# Concluída com atraso     259
# Desligada                244
# Transf. externa          103
# Transf. interna            6
# Integralizada              5
# Name: count, dtype: int64

# %% [markdown]
# #### 1.13 Concatenação dos tipos de curso com o tipo de oferta e exclusão de coluna "Tipo de Oferta"

# %%
df_restinga["Tipo de Curso"].unique()
# Out:
# array(['Tecnologia', 'Técnico', 'Licenciatura'], dtype=object)

# %%
df_restinga["Tipo de Oferta"].unique()
# Out:
# array(['Não se aplica', 'Integrado', 'Subsequente', 'PROEJA - Integrado',
#        'Concomitante'], dtype=object)

# %%
# Licenciatura para Superior-Licenciatura
df_restinga.loc[
    df_restinga["Tipo de Curso"] == "Licenciatura",
    "Tipo de Curso"
] = "Superior-Licenciatura"

# Tecnologia para Superior-Tecnologia
df_restinga.loc[
    df_restinga["Tipo de Curso"] == "Tecnologia",
    "Tipo de Curso"
] = "Superior-Tecnologia"

# Técnico para Técnico + Tipo de Oferta
df_restinga.loc[df_restinga["Tipo de Curso"] == "Técnico", "Tipo de Curso"] = (
    "Técnico-" + df_restinga.loc[df_restinga["Tipo de Curso"] == "Técnico", "Tipo de Oferta"]
)

# %%
df_restinga["Tipo de Curso"].unique()
# Out:
# array(['Superior-Tecnologia', 'Técnico-Integrado', 'Técnico-Subsequente',
#        'Técnico-PROEJA - Integrado', 'Superior-Licenciatura',
#        'Técnico-Concomitante'], dtype=object)

# %%
df_restinga = df_restinga.drop(columns=["Tipo de Oferta"])
print("Após exclusão de colunas desnecessárias:", df_restinga.shape)
# Out:
# Após exclusão de colunas desnecessárias: (10445, 18)

# %% [markdown]
# #### 1.14 Padronização das Categorias de Situação de Matrícula:

# %%
df_restinga["Categoria da Situação"].unique()
# Out:
# array(['Em curso', 'Evadidos', 'Concluintes', 'Em Curso', 'Concluídos'],
#       dtype=object)

# %%
concluidos = df_restinga[df_restinga["Categoria da Situação"].isin(["Concluídos"])]
concluidos["Situação de Matrícula"].unique()
# Out:
# array(['Concluída com atraso', 'Concluída no prazo'], dtype=object)

# %%
concluintes = df_restinga[df_restinga["Categoria da Situação"].isin(["Concluintes"])]
concluintes["Situação de Matrícula"].unique()
# Out:
# array(['Concluída no prazo', 'Integralizada', 'Concluída com atraso'],
#       dtype=object)

# %%
# Padronização do nome da Categoria Situação Em Curso e Ajuste dos Concluídos para Concluintes (todos encontram-se em alguma Situação de Matrícula de finalização):
df_restinga.loc[:, "Categoria da Situação"] = df_restinga["Categoria da Situação"].replace({
    "Em Curso": "Em curso",
    "Concluídos": "Concluintes"
})

df_restinga["Categoria da Situação"].unique()
# Out:
# array(['Em curso', 'Evadidos', 'Concluintes'], dtype=object)

# %%
df_restinga["Categoria da Situação"].value_counts()
# Out:
# Categoria da Situação
# Em curso       9000
# Evadidos        802
# Concluintes     643
# Name: count, dtype: int64

# %% [markdown]
# #### 1.15 Criação de coluna auxiliar ("Concluinte Previsto") para posterior cálculo do indicador de Taxa de Eficiência Acadêmica:

# %%
# marca True quando o ciclo deveria terminar no mesmo ano de referência da matrícula
df_restinga["Concluinte_Previsto"] = (
    df_restinga["Data de Fim Previsto do Ciclo"].dt.year == df_restinga["Ano"]
)
df_restinga.head()
# Out:
#         Ano Categoria da Situação     Cor / Raça  Código da Matricula  \
# 20729  2017              Em curso  Não declarada             44681986
# 42257  2017              Em curso         Branca             66262145
# 42258  2017              Em curso         Branca             66262155
# 42261  2017              Em curso         Branca             66262151
# 42264  2017              Evadidos         Branca             66262139
#
#        Código do Ciclo Matricula Data de Fim Previsto do Ciclo  \
# 20729                    1207788                    2014-12-22
# 42257                    2007734                    2019-12-20
# 42258                    2007734                    2019-12-20
# 42261                    2007734                    2019-12-20
# 42264                    2007734                    2019-12-20
#
#       Data de Inicio do Ciclo Data de Ocorrencia da Matricula  \
# 20729              2012-03-05                      2012-03-01
# 42257              2016-02-22                      2016-02-01
# 42258              2016-02-22                      2016-02-01
# 42261              2016-02-22                      2016-02-01
# 42264              2016-02-22                      2016-02-01
#
#                        Eixo Tecnológico  Faixa Etária  \
# 20729          Informação e Comunicação  35 a 39 anos
# 42257  Controle e Processos Industriais  15 a 19 anos
# 42258  Controle e Processos Industriais  15 a 19 anos
# 42261  Controle e Processos Industriais  15 a 19 anos
# 42264  Controle e Processos Industriais  15 a 19 anos
#
#       Mês De Ocorrência da Situação                          Nome de Curso  \
# 20729                    2018-03-05  Análise e Desenvolvimento de Sistemas
# 42257                    2016-02-01                  Técnico em Eletrônica
# 42258                    2016-02-01                  Técnico em Eletrônica
# 42261                    2016-02-01                  Técnico em Eletrônica
# 42264                    2017-05-01                  Técnico em Eletrônica
#
#       Renda Familiar Sexo Situação de Matrícula Subeixo Tecnológico  \
# 20729  Não declarada    F                Retido         Informática
# 42257     0,5<RFP<=1    F              Em fluxo            Elétrica
# 42258     0,5<RFP<=1    F              Em fluxo            Elétrica
# 42261     0<RFP<=0,5    F              Em fluxo            Elétrica
# 42264     0<RFP<=0,5    F       Transf. externa            Elétrica
#
#              Tipo de Curso     Turno  Concluinte_Previsto
# 20729  Superior-Tecnologia  Matutino                False
# 42257    Técnico-Integrado  Matutino                False
# 42258    Técnico-Integrado  Matutino                False
# 42261    Técnico-Integrado  Matutino                False
# 42264    Técnico-Integrado  Matutino                False

# %% [markdown]
# #### 1.16 Verificação de duplicatas:

# %%
print("Quantidade de duplicatas: ",df_restinga.duplicated().sum())
# Out:
# Quantidade de duplicatas:  0

# %% [markdown]
# #### 1.17 Inspeção detalhada:

# %%
df_restinga.info(memory_usage='deep') #para verificar a utilização de memória real
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10445 entries, 20729 to 1981342
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano                              10445 non-null  int64
#  1   Categoria da Situação            10445 non-null  object
#  2   Cor / Raça                       10445 non-null  object
#  3   Código da Matricula              10445 non-null  int64
#  4   Código do Ciclo Matricula        10445 non-null  int64
#  5   Data de Fim Previsto do Ciclo    10445 non-null  datetime64[ns]
#  6   Data de Inicio do Ciclo          10445 non-null  datetime64[ns]
#  7   Data de Ocorrencia da Matricula  10445 non-null  datetime64[ns]
#  8   Eixo Tecnológico                 10445 non-null  object
#  9   Faixa Etária                     10445 non-null  object
#  10  Mês De Ocorrência da Situação    10445 non-null  datetime64[ns]
#  11  Nome de Curso                    10445 non-null  object
#  12  Renda Familiar                   10445 non-null  object
#  13  Sexo                             10445 non-null  object
#  14  Situação de Matrícula            10445 non-null  object
#  15  Subeixo Tecnológico              10445 non-null  object
#  16  Tipo de Curso                    10445 non-null  object
#  17  Turno                            10445 non-null  object
#  18  Concluinte_Previsto              10445 non-null  bool
# dtypes: bool(1), datetime64[ns](4), int64(3), object(11)
# memory usage: 8.5 MB

# %% [markdown]
# #### 1.18 Exportando o DataFrame para .parquet

# %%
df_restinga.to_parquet("restinga_dados_tratados.parquet", index=False)

# %%
#df_restinga.to_csv("restinga_dados_tratados.csv", index=False)
